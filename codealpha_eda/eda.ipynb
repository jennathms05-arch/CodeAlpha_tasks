# %%
# =====================================
# TASK 2: Exploratory Data Analysis (EDA)
# Internship Ready Program
# =====================================

import pandas as pd
import matplotlib.pyplot as plt

# ---------------- STEP 1: Define Data ----------------
data = {
    'Age': [22, 25, 30, 35, 40],
    'Salary': [20000, 25000, 30000, 40000, 50000],
    'Experience': [1, 2, 5, 8, 12]
}

df = pd.DataFrame(data)

print("STEP 1: Dataset Loaded Successfully")
print(df)

# ---------------- STEP 2: Meaningful Questions ----------------
print("\nSTEP 2: Meaningful Questions")
print("1. What is the average salary?")
print("2. How does salary vary with age?")
print("3. What is the distribution of salary?")
print("4. How experience affects salary?")
print("5. What are the minimum and maximum values?")

# ---------------- STEP 3: Data Structure Exploration ----------------
print("\nSTEP 3: Data Structure")
print("Shape (Rows, Columns):", df.shape)
print("Column Names:", df.columns.tolist())
print("\nData Types:")
print(df.dtypes)

# ---------------- STEP 4: Summary Statistics ----------------
print("\nSTEP 4: Summary Statistics")
print(df.describe())

# ---------------- STEP 5: Data Visualization ----------------

# Salary Distribution - Histogram
plt.figure()
plt.hist(df['Salary'])
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.title("Salary Distribution")
plt.show()

# Age vs Salary - Scatter Plot
plt.figure()
plt.scatter(df['Age'], df['Salary'])
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary")
plt.show()

# Experience vs Salary - Line Chart
plt.figure()
plt.plot(df['Experience'], df['Salary'])
plt.xlabel("Experience (Years)")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
plt.show()

print("\nEDA Task 2 Completed Successfully ✅")
# Out:
# STEP 1: Dataset Loaded Successfully
#    Age  Salary  Experience
# 0   22   20000           1
# 1   25   25000           2
# 2   30   30000           5
# 3   35   40000           8
# 4   40   50000          12
#
# STEP 2: Meaningful Questions
# 1. What is the average salary?
# 2. How does salary vary with age?
# 3. What is the distribution of salary?
# 4. How experience affects salary?
# 5. What are the minimum and maximum values?
#
# STEP 3: Data Structure
# Shape (Rows, Columns): (5, 3)
# Column Names: ['Age', 'Salary', 'Experience']
#
# Data Types:
# Age           int64
# Salary        int64
# Experience    int64
# dtype: object
#
# STEP 4: Summary Statistics
#              Age        Salary  Experience
# count   5.000000      5.000000    5.000000
# mean   30.400000  33000.000000    5.600000
# std     7.300685  12041.594579    4.505552
# min    22.000000  20000.000000    1.000000
# 25%    25.000000  25000.000000    2.000000
# 50%    30.000000  30000.000000    5.000000
# ...

# %%
# !pip install pandas matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 25.3 is available.
# You should consider upgrading via the 'c:\users\hp\onedrive\desktop\task1 webscraping\codealpha_webscraping\.venv\scripts\python.exe -m pip install --upgrade pip' command.

# %%
impot pandas as pd
import matplotlib.pyplot  as plt
print("Working fine")
# Out:
#   Cell In[1], line 1
#     impot pandas as pd
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import matplotlib.pyplot  as plt
print("Working fine")
# Out:
# Working fine
